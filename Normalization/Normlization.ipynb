# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler # MinMaxScaler is the Normalization library
# import matplotlib.pyplot as plt


normalization_scaler = MinMaxScaler() # modify MinMaxScaler to the normalization_scaler

data = pd.read_csv('USGasB_Normalization.csv')
convert_normalization = normalization_scaler.fit_transform(data)
convert_normalization



# print(data.isna().any()) check the data
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.        ],
#        [0.02702703, 0.02139092, 0.04492072, 0.00384986, 0.02844703,
#         0.0322136 , 0.01965066],
#        [0.05405405, 0.03189792, 0.0795914 , 0.01443696, 0.05763607,
#         0.04922731, 0.02401747],
#        [0.08108108, 0.05529594, 0.11994139, 0.01732435, 0.08634499,
#         0.06954219, 0.02620087],
#        [0.10810811, 0.07323522, 0.1436795 , 0.01828681, 0.11735629,
#         0.05865922, 0.03165939],
#        [0.13513514, 0.1048234 , 0.18786767, 0.02598653, 0.14905504,
#         0.09660451, 0.0349345 ],
#        [0.16216216, 0.12397263, 0.21100398, 0.03657363, 0.18148488,
#         0.10632663, 0.04585153],
#        [0.18918919, 0.13928485, 0.23008686, 0.03079885, 0.2151041 ,
#         0.11601248, 0.05786026],
#        [0.21621622, 0.148387  , 0.25390195, 0.03176131, 0.24672646,
#         0.10676195, 0.06550218],
# ...
