# %%
# !pip install category_encoders
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
from category_encoders import TargetEncoder

TE = TargetEncoder()

data = pd.read_csv('homeprices.csv')
data['town'] = TE.fit_transform(data['town'], data['area']) # mean value of target calculate in this case area

data
# Out:
#            town  area   price
# 0   3170.570801  2600  550000
# 1   3170.570801  3000  565000
# 2   3170.570801  3200  610000
# 3   3170.570801  3600  680000
# 4   3170.570801  4000  725000
# 5   3134.201308  2600  585000
# 6   3134.201308  2800  615000
# 7   3134.201308  3300  650000
# 8   3134.201308  3600  710000
# 9   3130.001768  2600  575000
# 10  3130.001768  2900  600000
# 11  3130.001768  3100  620000
# 12  3130.001768  3600  695000
